# %%
import numpy as np
import pandas as pd

# %% [markdown]
# RNN Model Parameters

# %%
batchSize = 24
#lstmUnits = 64 # Not used
numClasses = 2  # Binary classification
#numClasses = 5
hiddenSize = 50

# %% [markdown]
# ## Word Vectors

# %%
from pathlib import Path
import os.path
wordsList = np.load(os.path.join(str(Path.home()), '.kaggle/wordvectors/pretrained_glove/wordsList.npy'))
wordsList = wordsList.tolist() #Originally loaded as numpy array
wordsList = [word.decode('UTF-8') for word in wordsList] #Encode words as UTF-8
wordVectors = np.load(os.path.join(str(Path.home()), '.kaggle/wordvectors/pretrained_glove/wordVectors.npy'))

# %% [markdown]
# Word Vectors have dimension 50

# %%
embedding_dimension = 50

# %% [markdown]
# ## Reviews

# %% [markdown]
# Load the Reviews

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /home/matt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
review_df = pd.read_csv('~/.kaggle/datasets/snap/amazon-fine-food-reviews/Reviews.csv', encoding='utf8')
review_df = review_df.drop(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Time', 'Summary'], axis=1)

# %% [markdown]
# For development, just use 5000 rows for simplicity and speed

# %%
one_df = review_df[review_df.Score == 1]
one_df.reset_index()

five_df = review_df[review_df.Score == 5]
five_df.reset_index()
# Out:
#          index  Score                                               Text
# 0            0      5  I have bought several of the Vitality canned d...
# 1            4      5  Great taffy at a great price.  There was a wid...
# 2            6      5  This saltwater taffy had great flavors and was...
# 3            7      5  This taffy is so good.  It is very soft and ch...
# 4            8      5  Right now I'm mostly just sprouting this so my...
# 5            9      5  This is a very healthy dog food. Good for thei...
# 6           10      5  I don't know if it's the cactus or the tequila...
# 7           11      5  One of my boys needed to lose some weight and ...
# 8           14      5  The Strawberry Twizzlers are my guilty pleasur...
# 9           15      5  My daughter loves twizzlers and this shipment ...
# 10          17      5  I am very satisfied with my Twizzler purchase....
# 11          18      5  Twizzlers, Strawberry my childhood favorite ca...
# 12          19      5  Candy was delivered very fast and was purchase...
# 13          20      5  My husband is a Twizzlers addict.  We've bough...
# 14          21      5  I bought these for my husband who is currently...
# 15          22      5  I can remember buying this candy as a kid and ...
# 16          23      5  I love this candy.  After weight watchers I ha...
# 17          24      5  I have lived out of the US for over 7 yrs now,...
# 18          25      5  Product received is as advertised.<br /><br />...
# 19          28      5  I got this for my Mum who is not diabetic but ...
# 20          29      5  I don't know if it's the cactus or the tequila...
# 21          30      5  I have never been a huge coffee fan. However, ...
# 22          31      5  This offer is a great price and a great taste,...
# 23          34      5  Instant oatmeal can become soggy the minute th...
# 24          36      5  For those of us with celiac disease this produ...
# 25          37      5  What else do you need to know? Oatmeal, instan...
# 26          39      5  I ordered this for my wife as it was reccomend...
# 27          40      5  The variety packs taste great!<br /><br />I ha...
# 28          41      5  McCann's makes oatmeal for every oatmeal conno...
# 29          42      5  I have McCann's Oatmeal every morning and by o...
# ...        ...    ...                                                ...
# 363092  568410      5  My main reason for the five star review has to...
# 363093  568411      5  I bought this to try on two registered Maine C...
# 363094  568412      5  When we brought home two 3-month-old purebred ...
# 363095  568414      5  This is always a good product for Exotic Cats....
# 363096  568415      5                   as it should be for $6 a bottle.
# 363097  568418      5  we just had a new lawn put in and it was very ...
# 363098  568419      5  I have been using this product for two years n...
# 363099  568421      5  Pacific Chai coconut Chai Latte is so good. I ...
# 363100  568423      5  I bought this candy for my son, who spent time...
# 363101  568424      5  I've tried several violet flavored candies in ...
# 363102  568425      5  This candy has a very good flavor. It is quite...
# 363103  568427      5  I had been looking for the violet candy with t...
# 363104  568428      5  these are very pricey so i only enjoy them now...
# 363105  568429      5  These candies have a mild flavor, when compare...
# 363106  568430      5  This product is a bit pricey for the amt. rece...
# 363107  568436      5  In the past, I would have to buy a large quant...
# 363108  568437      5  Ammonium bicarbonate in a nice little package....
# 363109  568438      5  If you haven't ever used Ammonium Bicarbonate ...
# 363110  568440      5  Indie Candy's gummies are absolutely delicious...
# 363111  568441      5  Quick and easy! Had similar Gulasch in Guest H...
# 363112  568442      5  This product is great.  Gives you so much ener...
# 363113  568443      5  I love this tea.  I first discovered the pleas...
# 363114  568444      5  As a foodie, I use a lot of Chinese 5 Spice po...
# 363115  568445      5  You can make this mix yourself, but the Star A...
# 363116  568447      5  Hoping there is no MSG in this, this tastes ex...
# 363117  568448      5  My only complaint is that there's so much of i...
# 363118  568449      5  Great for sesame chicken..this is a good if no...
# 363119  568451      5  These stars are small, so you can give 10-15 o...
# 363120  568452      5  These are the BEST treats for training and rew...
# 363121  568453      5  I am very satisfied ,product is as advertised,...
#
# [363122 rows x 3 columns]

# %%
#numReviews = 12500  # This works
numReviews = 25000

# %%
one_df = one_df[0:numReviews]
five_df = five_df[0:numReviews]

# %% [markdown]
# Lowercase, and then tokenize the reviews.  The tokens need to be lowercase for the embedding lookup.

# %%
# one_df['Length'] = one_df['Tokens'].apply(lambda token_list: len(token_list))
# one_df['Length'].min()
# five_df['Length'] = five_df['Tokens'].apply(lambda token_list: len(token_list))
# five_df['Length'].min()

# %%
import re

strip_special_chars = re.compile("[^A-Za-z0-9 ]+")

def cleanSentences(string):
    return word_tokenize(re.sub(strip_special_chars, " ", string.lower()))

one_df['Tokens'] = one_df['Text'].apply(lambda text: cleanSentences(text))
five_df['Tokens'] = five_df['Text'].apply(lambda text: cleanSentences(text))

# %% [markdown]
# Create the array of input sentences converted to word IDs

# %%
#maxSeqLength = 250  # Determined by EDA
maxSeqLength = 200  # This works, in combination with numReviews = 12500

# %%
word_ids = np.zeros((2*numReviews, maxSeqLength), dtype='int32')

# %% [markdown]
# Convert words to word IDs and store in word_ids

# %%
sentence_index = 0

for _, row in one_df.iterrows():
    
    word_index = 0
    
    for word in row['Tokens']:

        try:
            word_ids[sentence_index][word_index] = wordsList.index(word)
        except ValueError:
            word_ids[sentence_index][word_index] = 399999 #Vector for unkown words
        
        word_index = word_index + 1

        if word_index == maxSeqLength:
            break
    
    sentence_index = sentence_index + 1

for _, row in five_df.iterrows():
    
    word_index = 0
    
    for word in row['Tokens']:

        try:
            word_ids[sentence_index][word_index] = wordsList.index(word)
        except ValueError:
            word_ids[sentence_index][word_index] = 399999 #Vector for unkown words
        
        word_index = word_index + 1

        if word_index == maxSeqLength:
            break
    
    sentence_index = sentence_index + 1

# %% [markdown]
# Create functions to get the train and test batches

# %% [markdown]
# TODO: Look into replacing these functions with Tensorflow's data iterators

# %%
from random import randint

def getTrainBatch():
    labels = []
    arr = np.zeros([batchSize, maxSeqLength])
    for i in range(batchSize):
        if (i % 2 == 0): 
            num = randint(1,numReviews)
            labels.append([1,0])
        else:
            num = randint(numReviews+1,2*numReviews)
            labels.append([0,1])
        arr[i] = word_ids[num-1:num]
    return arr, labels

# def getTestBatch():
#     labels = []
#     arr = np.zeros([batchSize, maxSeqLength])
#     for i in range(batchSize):
#         num = randint(11499,13499)
#         if (num <= 12499):
#             labels.append([1,0])
#         else:
#             labels.append([0,1])
#         arr[i] = ids[num-1:num]
#     return arr, labels

# %% [markdown]
# Reset the batch iterators

# %% [markdown]
# ## Tensorflow Model

# %% [markdown]
# Hyper Parameters

# %%
learning_rate =  0.001
dropout_keep_prob = 0.75
#dropout_keep_prob = 0.9

# %% [markdown]
# Model

# %%
import tensorflow as tf
tf.reset_default_graph()

labels = tf.placeholder(tf.float32, [batchSize, numClasses])
input_data = tf.placeholder(tf.int32, [batchSize, maxSeqLength])

data = tf.Variable(tf.zeros([batchSize, maxSeqLength, embedding_dimension]), dtype=tf.float32)
data = tf.nn.embedding_lookup(wordVectors, input_data)

lstmCell = tf.contrib.rnn.BasicLSTMCell(hiddenSize)
lstmCell = tf.contrib.rnn.DropoutWrapper(cell=lstmCell, output_keep_prob=dropout_keep_prob)
rnn_out, _ = tf.nn.dynamic_rnn(lstmCell, data, dtype=tf.float32)

W_out = tf.Variable(tf.truncated_normal([hiddenSize, numClasses]), dtype=tf.float32)
b_out = tf.Variable(tf.constant(0.1, shape=[numClasses]), dtype=tf.float32)

# Get the output of the last RNN cell
rnn_out = tf.transpose(rnn_out, [1, 0, 2])
last_cell_out = tf.gather(rnn_out, int(rnn_out.get_shape()[0]) - 1)

# Calculate logits
logits = (tf.matmul(last_cell_out, W_out) + b_out)

# Calculate prediction and accuracy
prediction = tf.argmax(logits,1)
correctPred = tf.equal(prediction, tf.argmax(labels,1))
accuracy = tf.reduce_mean(tf.cast(correctPred, tf.float32))

# Loss function and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# %% [markdown]
# ## Train Model

# %%
import datetime

def TrainModel(session, writer):
    
    start_time = datetime.datetime.now()
    
    i = 0  # Must stay outside the loops
    
    for epoch in range(100000):
        
        # Next Batch of reviews
        nextBatch, nextBatchLabels = getTrainBatch()

        feed_dict_ = {
            input_data: nextBatch,
            labels: nextBatchLabels
        }

        loss_, _ = session.run([loss, optimizer], feed_dict=feed_dict_)

        #Write summary to Tensorboard
        if (i % 10 == 0):
            summary = session.run(merged, {input_data: nextBatch, labels: nextBatchLabels})
            writer.add_summary(summary, i)

        if (i % 500 == 0):
            print("Loss is: ", loss_, ", ", (datetime.datetime.now() - start_time).seconds, " seconds")

        i = i + 1

# %% [markdown]
# ## Train and Test

# %% [markdown]
# Use the following:
# tensorboard --logdir=tensorboard

# %%
import datetime

with tf.Session() as sess:
    #saver = tf.train.Saver()
    sess.run(tf.global_variables_initializer())
    
    tf.summary.scalar('Loss', loss)
    tf.summary.scalar('Accuracy', accuracy)
    merged = tf.summary.merge_all()
    logdir = "tensorboard/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "/"
    writer = tf.summary.FileWriter(logdir, sess.graph)
        
    # Train model
    TrainModel(sess, writer)
    
    # Test model
    #TestModel(sess)
    
    writer.close()
